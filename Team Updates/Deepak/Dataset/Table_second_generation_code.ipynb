# %%
import pandas as pd
import os
file_path = "cleaned_sales_dataset.xlsx"
if not os.path.exists(file_path):
    raise FileNotFoundError(f"File not found at: {file_path}")
df = pd.read_excel(file_path)
print("🔹 DataFrame shape (rows, columns):")
print(df.shape)

print("\n🔹 Column names:")
print(df.columns.tolist())
print("\n🔹 First 10 rows of DataFrame:")
print(df.head(10))
print("\n🔹 First 20 rows (full width):")
print(df.head(20).to_string(index=False))
print("\n🔹 Data types:")
print(df.dtypes)
invoice_rows = df[
    df["FIRM"].notna() &
    df["FIRM_PRODUCT"].isna()
]

print("\n🔹 Invoice-level rows preview:")
print(invoice_rows.head(10).to_string(index=False))
# Out:
# 🔹 DataFrame shape (rows, columns):
# (1753, 15)
#
# 🔹 Column names:
# ['Date', 'FIRM', 'FIRM_PRODUCT', 'Voucher Type', 'Voucher No.', 'GSTIN/UIN', 'Quantity', 'Alt. Units', 'Rate', 'Value', 'Gross Total', 'SALE @18% LOCAL', 'CGST@9%', 'SGST@9%', 'Round Off']
#
# 🔹 First 10 rows of DataFrame:
#         Date                         FIRM  \
# 0 2025-12-01     SHREE BALAJI ENTERPRISES
# 1        NaT     SHREE BALAJI ENTERPRISES
# 2 2025-12-01  WORLDWIDE SECURITY SOLUTION
# 3        NaT  WORLDWIDE SECURITY SOLUTION
# 4        NaT  WORLDWIDE SECURITY SOLUTION
# 5 2025-12-01          AVIATION TECHNOLOGY
# 6        NaT          AVIATION TECHNOLOGY
# 7 2025-12-01          QUADRA SECURITY LLP
# 8        NaT          QUADRA SECURITY LLP
# 9        NaT          QUADRA SECURITY LLP
#
#                                         FIRM_PRODUCT Voucher Type  \
# 0                                                NaN        Sales
# 1                          HIK VDP ANALOG DS-KIS204T          NaN
# 2                                                NaN        Sales
# 3                          CP-UNR-4K2161-V4-16CH NVR          NaN
# 4  CP-UNC-DA21PL3C-L-Y 2 MP AUDIO NETWORK DOME CA...          NaN
# 5                                                NaN        Sales
# 6               DAICHI PVC WIRE CAT 6 CCA 100MTR ECO          NaN
# 7                                                NaN        Sales
# 8          32CH NVR (2HDD Aisense NVR)PT-NRAS2B32-K4          NaN
# 9                               4K HDMI CABLE 10MTR.          NaN
#
#       Voucher No.        GSTIN/UIN  Quantity  Alt. Units      Rate      Value  \
# 0  SAS/25-26/7782  06BXMPL2769M1ZR       1.0         NaN       NaN    3855.93
# 1             NaN              NaN       1.0         NaN   3855.93    3855.93
# 2  SAS/25-26/7783  06DQJPK7817P1Z2      12.0         NaN       NaN   28177.92
# 3             NaN              NaN       1.0         NaN   4872.88    4872.88
# 4             NaN              NaN      11.0         NaN   2118.64   23305.04
# 5  SAS/25-26/7784  06ABCFA7434K1ZF       1.0         NaN       NaN     847.46
# 6             NaN              NaN       1.0         NaN    847.46     847.46
# 7  SAS/25-26/7785  06AABFQ3487G1Z6     160.0         NaN       NaN  266232.10
# 8             NaN              NaN       1.0         NaN  16720.34   16720.34
# 9             NaN              NaN       1.0         NaN    233.05     233.05
#
#    Gross Total  SALE @18% LOCAL   CGST@9%   SGST@9%  Round Off
# 0       4550.0          3855.93    347.03    347.03       0.01
# 1          NaN              NaN       NaN       NaN        NaN
# 2      33250.0         28177.92   2536.01   2536.01       0.06
# 3          NaN              NaN       NaN       NaN        NaN
# 4          NaN              NaN       NaN       NaN        NaN
# 5       1000.0           847.46     76.27     76.27        NaN
# 6          NaN              NaN       NaN       NaN        NaN
# 7     314154.0        266232.10  23960.91  23960.91       0.08
# 8          NaN              NaN       NaN       NaN        NaN
# 9          NaN              NaN       NaN       NaN        NaN
#
# 🔹 First 20 rows (full width):
#       Date                        FIRM                                       FIRM_PRODUCT Voucher Type    Voucher No.       GSTIN/UIN  Quantity  Alt. Units     Rate     Value  Gross Total  SALE @18% LOCAL  CGST@9%  SGST@9%  Round Off
# 2025-12-01    SHREE BALAJI ENTERPRISES                                                NaN        Sales SAS/25-26/7782 06BXMPL2769M1ZR       1.0         NaN      NaN   3855.93       4550.0          3855.93   347.03   347.03       0.01
#        NaT    SHREE BALAJI ENTERPRISES                          HIK VDP ANALOG DS-KIS204T          NaN            NaN             NaN       1.0         NaN  3855.93   3855.93          NaN              NaN      NaN      NaN        NaN
# 2025-12-01 WORLDWIDE SECURITY SOLUTION                                                NaN        Sales SAS/25-26/7783 06DQJPK7817P1Z2      12.0         NaN      NaN  28177.92      33250.0         28177.92  2536.01  2536.01       0.06
#        NaT WORLDWIDE SECURITY SOLUTION                          CP-UNR-4K2161-V4-16CH NVR          NaN            NaN             NaN       1.0         NaN  4872.88   4872.88          NaN              NaN      NaN      NaN        NaN
#        NaT WORLDWIDE SECURITY SOLUTION CP-UNC-DA21PL3C-L-Y 2 MP AUDIO NETWORK DOME CAMERA          NaN            NaN             NaN      11.0         NaN  2118.64  23305.04          NaN              NaN      NaN      NaN        NaN
# 2025-12-01         AVIATION TECHNOLOGY                                                NaN        Sales SAS/25-26/7784 06ABCFA7434K1ZF       1.0         NaN      NaN    847.46       1000.0           847.46    76.27    76.27        NaN
#        NaT         AVIATION TECHNOLOGY               DAICHI PVC WIRE CAT 6 CCA 100MTR ECO          NaN            NaN             NaN       1.0         NaN   847.46    847.46          NaN              NaN      NaN      NaN        NaN
# 2025-12-01         QUADRA SECURITY LLP                                                NaN        Sales SAS/25-26/7785 06AABFQ3487G1Z6     160.0         NaN      NaN 266232.10     314154.0        266232.10 23960.91 23960.91       0.08
#        NaT         QUADRA SECURITY LLP          32CH NVR (2HDD Aisense NVR)PT-NRAS2B32-K4          NaN            NaN             NaN       1.0         NaN 16720.34  16720.34          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP                               4K HDMI CABLE 10MTR.          NaN            NaN             NaN       1.0         NaN   233.05    233.05          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP                                    CAMERA BOX  5X5          NaN            NaN             NaN      32.0         NaN    12.71    406.72          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP                              CP PLUS 4MP (CP-Z43A)          NaN            NaN             NaN       1.0         NaN  2966.10   2966.10          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP            CP PLUS CAT 6 ( CP-EUT-6TGL1-305) 23AWG          NaN            NaN             NaN       2.0         NaN  5550.85  11101.70          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP          CP FULL GIGA SWITCH 24 PORT (GPU24G2F2-30          NaN            NaN             NaN       1.0         NaN 10593.22  10593.22          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP            CP POE 8PORT 10/100 (CP-DNW-HPU8H2-N12)          NaN            NaN             NaN       1.0         NaN  1059.32   1059.32          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP                 CP-UNC-DA41L3C-D-LQ MP IP DOME D/L          NaN            NaN             NaN      10.0         NaN  2669.49  26694.90          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP              CP-UNC-TA41L3C-D-LQ 4MP IP BULLET D/L          NaN            NaN             NaN       3.0         NaN  2855.93   8567.79          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP                                   CP-UNR-4K2162-V3          NaN            NaN             NaN       1.0         NaN  5478.81   5478.81          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP    CP UTP 24AWG CAT-6 100 MTR. (CP-EUT-6TGL23-100)          NaN            NaN             NaN       1.0         NaN  1855.93   1855.93          NaN              NaN      NaN      NaN        NaN
#        NaT         QUADRA SECURITY LLP                                CS-CMT-SOLARPANEL-E          NaN            NaN             NaN       1.0         NaN  1313.56   1313.56          NaN              NaN      NaN      NaN        NaN
#
# 🔹 Data types:
# Date               datetime64[ns]
# FIRM                       object
# FIRM_PRODUCT               object
# Voucher Type               object
# Voucher No.                object
# GSTIN/UIN                  object
# Quantity                  float64
# Alt. Units                float64
# Rate                      float64
# Value                     float64
# Gross Total               float64
# SALE @18% LOCAL           float64
# CGST@9%                   float64
# SGST@9%                   float64
# Round Off                 float64
# dtype: object
#
# 🔹 Invoice-level rows preview:
#       Date                          FIRM FIRM_PRODUCT Voucher Type    Voucher No.       GSTIN/UIN  Quantity  Alt. Units  Rate     Value  Gross Total  SALE @18% LOCAL  CGST@9%  SGST@9%  Round Off
# 2025-12-01      SHREE BALAJI ENTERPRISES          NaN        Sales SAS/25-26/7782 06BXMPL2769M1ZR       1.0         NaN   NaN   3855.93       4550.0          3855.93   347.03   347.03       0.01
# 2025-12-01   WORLDWIDE SECURITY SOLUTION          NaN        Sales SAS/25-26/7783 06DQJPK7817P1Z2      12.0         NaN   NaN  28177.92      33250.0         28177.92  2536.01  2536.01       0.06
# 2025-12-01           AVIATION TECHNOLOGY          NaN        Sales SAS/25-26/7784 06ABCFA7434K1ZF       1.0         NaN   NaN    847.46       1000.0           847.46    76.27    76.27        NaN
# 2025-12-01           QUADRA SECURITY LLP          NaN        Sales SAS/25-26/7785 06AABFQ3487G1Z6     160.0         NaN   NaN 266232.10     314154.0        266232.10 23960.91 23960.91       0.08
# 2025-12-01            KWALITY TECHNOLOGY          NaN        Sales SAS/25-26/7786 06AJZPC7774M1Z9      13.0         NaN   NaN  11059.34      13050.0         11059.34   995.34   995.34       0.02
# 2025-12-01     RP MULTI SOLUTION PVT LTD          NaN        Sales SAS/25-26/7787 06AALCR2823A1ZR       1.0         NaN   NaN    889.83       1050.0           889.83    80.08    80.08       0.01
# 2025-12-01           MANISH CCTV GURGAON          NaN        Sales SAS/25-26/7788             NaN      10.0         NaN   NaN   1237.29       1460.0          1237.29   111.35   111.35       0.01
# 2025-12-01 SPEED TRACK SECURITY SOLUTION          NaN        Sales SAS/25-26/7789 06CFPPP1717K1Z2      13.0         NaN   NaN  12542.36      14800.0         12542.36  1128.81  1128.81       0.02
# 2025-12-01            ARNAV IT SOLUTIONS          NaN        Sales SAS/25-26/7790 06DOFPK1129N1ZT       1.0         NaN   NaN   4406.78       5200.0          4406.78   396.61   396.61        NaN
# 2025-12-01             DIALTECH SOLUTION          NaN        Sales SAS/25-26/7791 06FCVPK8752H2ZT      21.0         NaN   NaN   4423.67       5220.0          4423.67   398.12   398.12       0.09

# %%
invoice_rows_clean = invoice_rows.copy()

# %%
cols_to_drop = [ "FIRM_PRODUCT", "Alt. Units", "Rate"]

invoice_rows_clean = invoice_rows_clean.drop(
    columns=cols_to_drop,
    errors="ignore"   # agar koi column missing ho to crash na ho
)

# %%
print("\n🔹 Cleaned Invoice-level DataFrame preview:")
print(invoice_rows_clean.head(10).to_string(index=False))

print("\n🔹 Columns after drop:")
print(invoice_rows_clean.columns.tolist())
# Out:
# 🔹 Cleaned Invoice-level DataFrame preview:
#       Date                          FIRM Voucher Type    Voucher No.       GSTIN/UIN  Quantity     Value  Gross Total  SALE @18% LOCAL  CGST@9%  SGST@9%  Round Off
# 2025-12-01      SHREE BALAJI ENTERPRISES        Sales SAS/25-26/7782 06BXMPL2769M1ZR       1.0   3855.93       4550.0          3855.93   347.03   347.03       0.01
# 2025-12-01   WORLDWIDE SECURITY SOLUTION        Sales SAS/25-26/7783 06DQJPK7817P1Z2      12.0  28177.92      33250.0         28177.92  2536.01  2536.01       0.06
# 2025-12-01           AVIATION TECHNOLOGY        Sales SAS/25-26/7784 06ABCFA7434K1ZF       1.0    847.46       1000.0           847.46    76.27    76.27        NaN
# 2025-12-01           QUADRA SECURITY LLP        Sales SAS/25-26/7785 06AABFQ3487G1Z6     160.0 266232.10     314154.0        266232.10 23960.91 23960.91       0.08
# 2025-12-01            KWALITY TECHNOLOGY        Sales SAS/25-26/7786 06AJZPC7774M1Z9      13.0  11059.34      13050.0         11059.34   995.34   995.34       0.02
# 2025-12-01     RP MULTI SOLUTION PVT LTD        Sales SAS/25-26/7787 06AALCR2823A1ZR       1.0    889.83       1050.0           889.83    80.08    80.08       0.01
# 2025-12-01           MANISH CCTV GURGAON        Sales SAS/25-26/7788             NaN      10.0   1237.29       1460.0          1237.29   111.35   111.35       0.01
# 2025-12-01 SPEED TRACK SECURITY SOLUTION        Sales SAS/25-26/7789 06CFPPP1717K1Z2      13.0  12542.36      14800.0         12542.36  1128.81  1128.81       0.02
# 2025-12-01            ARNAV IT SOLUTIONS        Sales SAS/25-26/7790 06DOFPK1129N1ZT       1.0   4406.78       5200.0          4406.78   396.61   396.61        NaN
# 2025-12-01             DIALTECH SOLUTION        Sales SAS/25-26/7791 06FCVPK8752H2ZT      21.0   4423.67       5220.0          4423.67   398.12   398.12       0.09
#
# 🔹 Columns after drop:
# ['Date', 'FIRM', 'Voucher Type', 'Voucher No.', 'GSTIN/UIN', 'Quantity', 'Value', 'Gross Total', 'SALE @18% LOCAL', 'CGST@9%', 'SGST@9%', 'Round Off']

# %%
print("🔹 Data types of invoice_rows_clean:\n")
print(invoice_rows_clean.dtypes)
# Out:
# 🔹 Data types of invoice_rows_clean:
#
# Date               datetime64[ns]
# FIRM                       object
# Voucher Type               object
# Voucher No.                object
# GSTIN/UIN                  object
# Quantity                  float64
# Value                     float64
# Gross Total               float64
# SALE @18% LOCAL           float64
# CGST@9%                   float64
# SGST@9%                   float64
# Round Off                 float64
# dtype: object

# %%
invoice_rows_clean["Date"] = invoice_rows_clean["Date"].dt.date

# %%
invoice_rows_clean["total_tax_amount"] = (
    invoice_rows_clean["CGST@9%"].fillna(0) +
    invoice_rows_clean["SGST@9%"].fillna(0)
)

# %%
print("\n🔹 Preview after changes:\n")
# Out:
# 🔹 Preview after changes:

# %%
required_columns = [
    "Date",
    "FIRM",
    "Voucher No.",
    "Quantity",
    "Value",
    "GSTIN/UIN",
    "total_tax_amount",
    "Gross Total"
]

# %%
final_invoice_df = invoice_rows_clean[
    [col for col in required_columns if col in invoice_rows_clean.columns]
].copy()

# %%
print("\n🔹 Final invoice dataset preview:\n")
print(final_invoice_df.head(10).to_string(index=False))

print("\n🔹 Columns being saved:\n")
print(final_invoice_df.columns.tolist())
# Out:
# 🔹 Final invoice dataset preview:
#
#       Date                          FIRM    Voucher No.  Quantity     Value       GSTIN/UIN  total_tax_amount  Gross Total
# 2025-12-01      SHREE BALAJI ENTERPRISES SAS/25-26/7782       1.0   3855.93 06BXMPL2769M1ZR            694.06       4550.0
# 2025-12-01   WORLDWIDE SECURITY SOLUTION SAS/25-26/7783      12.0  28177.92 06DQJPK7817P1Z2           5072.02      33250.0
# 2025-12-01           AVIATION TECHNOLOGY SAS/25-26/7784       1.0    847.46 06ABCFA7434K1ZF            152.54       1000.0
# 2025-12-01           QUADRA SECURITY LLP SAS/25-26/7785     160.0 266232.10 06AABFQ3487G1Z6          47921.82     314154.0
# 2025-12-01            KWALITY TECHNOLOGY SAS/25-26/7786      13.0  11059.34 06AJZPC7774M1Z9           1990.68      13050.0
# 2025-12-01     RP MULTI SOLUTION PVT LTD SAS/25-26/7787       1.0    889.83 06AALCR2823A1ZR            160.16       1050.0
# 2025-12-01           MANISH CCTV GURGAON SAS/25-26/7788      10.0   1237.29             NaN            222.70       1460.0
# 2025-12-01 SPEED TRACK SECURITY SOLUTION SAS/25-26/7789      13.0  12542.36 06CFPPP1717K1Z2           2257.62      14800.0
# 2025-12-01            ARNAV IT SOLUTIONS SAS/25-26/7790       1.0   4406.78 06DOFPK1129N1ZT            793.22       5200.0
# 2025-12-01             DIALTECH SOLUTION SAS/25-26/7791      21.0   4423.67 06FCVPK8752H2ZT            796.24       5220.0
#
# 🔹 Columns being saved:
#
# ['Date', 'FIRM', 'Voucher No.', 'Quantity', 'Value', 'GSTIN/UIN', 'total_tax_amount', 'Gross Total']

# %%
output_path = "Table_second.xlsx"

final_invoice_df.to_excel(output_path, index=False)

print(f"\n✅ Final invoice Excel file saved at:\n{output_path}")
# Out:
# ✅ Final invoice Excel file saved at:
# Table_second.xlsx

# %%
final_invoice_df.isnull().sum()
# Out:
# Date                 0
# FIRM                 0
# Voucher No.          0
# Quantity             2
# Value                2
# GSTIN/UIN           55
# total_tax_amount     0
# Gross Total          2
# dtype: int64
